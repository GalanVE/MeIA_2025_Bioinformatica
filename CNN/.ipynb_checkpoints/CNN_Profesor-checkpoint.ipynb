# %% [markdown]
# # Aprendizaje supervisado
#
# __Ciencia de datos en Biología__
#
# _Posgrado en Ciencias Biológicas_
#
# `2024-2`

# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# Para las computadoras, las imágenes son una colección de intensidades de píxeles almacenadas en un orden específico. Para nosotros, la imagen es una colección de colores. Hemos visto acertijos de imágenes, donde las imágenes se cortan en pequeñas subpartes y luego la tarea siguiente es volver a unir esas partes pequeñas para formar una imagen completa. Las subpartes por sí solas no tienen ningún significado. Este también es el caso de las redes neuronales simples.
#
# Si queremos entrenar una red neuronal artificial con datos de imágenes, tenemos que desconectar todos los píxeles de la imagen e introducir cada píxel en la red neuronal como una característica. Aunque las características individuales tienen información sobre la imagen, las imágenes son más comprensibles cuando los píxeles locales se ensamblan.
#
# ![picture](https://drive.google.com/uc?id=12HlY1VOd3FzU-Zuqle7i-EGlx6G8i8hv)
#
# En la Figura 13.10, podemos ver cómo una imagen se distorsiona cuando se introduce en redes neuronales.

# %% [markdown]
# Las redes neuronales convolucionales (CNN) son modelos de aprendizaje profundo bien conocidos para datos de imágenes o datos espaciales. Las CNN pueden aprender características espaciales locales, mientras que las ANN pueden aprender características individualmente. Una CNN utiliza una pequeña ventana o un filtro para aprender. La imagen se divide en pequeñas subpartes y se utilizan múltiples filtros para estudiar diferentes características locales, como bordes y texturas. De esta manera, estas características básicas se combinan para crear características de orden superior, como un ojo y una mano, entre otras.
# Estos filtros son métricas de números que se pueden entrenar o actualizar. Una CNN detecta las características necesarias de los datos de la imagen con los filtros entrenados correctos y extrae las características predictivas relevantes (Figura 13.11). Los filtros se optimizan con cada iteración mediante el método de retropropagación mencionado. Por diseño, la convolución es una función matemática en dos objetos que da como resultado cómo cambia un objeto mientras opera con otro objeto. Este proceso también se llama mapeo de características.
#
# ![picture](https://drive.google.com/uc?id=1ZYCj5t-ZFHZal16e0AbROZxih-6PDb2J)

# %% [markdown]
# Además, existen otras capas además de las capas convolucionales; estos se están acumulando y aplanando. El método de agrupación también desliza una ventana sobre los píxeles de una imagen y fusiona características locales en una sola característica. Las capas de agrupación pueden ser de muchos tipos:
#
# 1. La agrupación máxima se produce cuando se selecciona el píxel de máxima intensidad sobre los demás píxeles dentro de la ventana.
# 2. La agrupación promedio es cuando una ventana devuelve el promedio de todos los píxeles.
# La agrupación tiene como objetivo principal reducir el tamaño de los datos. En este paso, el modelo retiene información importante entre los píxeles locales, como la alta intensidad o el promedio de todos los píxeles, y elimina otra información insignificante.
# Después de extraer las características locales de las imágenes utilizando CNN y la operación de agrupación, estas características deben enviarse a las ANN para su clasificación. Por lo tanto, estas características 2D se convierten en características 1D utilizando la capa aplanada, que luego se ingresa a las ANN para su posterior procesamiento.
# La Figura 13.12 muestra una arquitectura básica de CNN basada en redes neuronales artificiales.
#
# ![picture](https://drive.google.com/uc?id=1x4FCEjKeyPMx7w-vHluAJ0aU2G2IxFE3)

# %% [markdown]
# Las redes neuronales convolucionales (CNN, por sus siglas en inglés) son un tipo de algoritmo de aprendizaje automático inspirado en el funcionamiento del cerebro humano y diseñado especialmente para procesar y analizar datos de imágenes.
#
# Las CNN son muy útiles en tareas relacionadas con la visión por computadora, como reconocimiento de objetos, clasificación de imágenes y detección de patrones visuales. Están compuestas por diferentes capas que realizan operaciones matemáticas especiales para extraer características relevantes de las imágenes y luego utilizar esas características para realizar predicciones o tomar decisiones.
#
# La idea principal detrás de las CNN es la convolución, que es una operación matemática que se aplica entre una ventana deslizante (llamada filtro o kernel) y una región de la imagen. El filtro se desliza por toda la imagen, multiplicando los valores de los píxeles en cada posición por los valores correspondientes en el filtro. Esta operación produce un nuevo mapa de características que resalta ciertas características de la imagen, como bordes, texturas o formas.
#
# Además de la convolución, las CNN también utilizan otras capas, como capas de activación (que introducen no linealidad al proceso), capas de agrupación (que reducen el tamaño de los mapas de características) y capas completamente conectadas (que realizan la clasificación final o toman decisiones basadas en las características extraídas).

# %% [markdown]
# # Convolution Neural Network
#
# ## Convolution layer
# Es la parte o segmento más importante del algoritmo de CNN. La notación matemática de Convolution es la siguiente:
#
# $(f*g)(t)=^{def}∫_{-∞}^∞ f(τ)g(t-τ)dτ$
#
# Aquí en la ecuación anterior, podemos inferir que la convolución es una integración de dos funciones simples (f y g).
#
# Tenemos dos términos, uno es nuestra entrada/conjunto de datos en formato de matriz y otro es el detector de características o kernel o filtros (Este será una matriz de 3*3 o 5*5 o 7*7, depende de la arquitectura que estemos utilizando).
#
# En comparación con la matriz de imagen de entrada, esta matriz es más pequeña, pero podemos obtener un conocimiento más profundo solo de esta parte del kernel.
#
# ![picture](https://miro.medium.com/v2/resize:fit:875/1*wpbLgTW_lopZ6JtDqVByuA.gif)
#
# Entonces, de todas las explicaciones anteriores, lo que inferimos de este bloque de CONVOLUCIÓN, la extracción de términos importantes, o técnicamente lo llamamos extracción de características. Por lo tanto, el bloque de convolución se utiliza para lograr la extracción de características del conjunto de datos dado evitando otras características sin importancia o atenuando o evitando información o característica inútil en simple.
#
# Los filtros juegan un papel importante en la transformación de los datos (números/píxeles), la salida resultante que llamamos mapas de activación, lo que significa regiones en las que se detecta un núcleo específico a partir de los datos de entrada. Dimensión del mapa de características = Dimensión del filtro
#
# Para el caso de las imagenes en formato RGB tenemos:
#
#
#
# ![picture](https://editor.analyticsvidhya.com/uploads/59164cnni.gif)

# %% [markdown]
# ### Función de activación
#
# Así que una vez que el proceso de convolución termina para nuestro conjunto de datos de entrada (¡proceso de deslizamiento!), el siguiente paso importante para proceder en el algoritmo de CNN es la función de activación.
#
# Cuando se compara con un modelo basado en neuronas que está en nuestros cerebros, la función de activación es al final decidir qué se va a disparar a la siguiente neurona. Toma la señal de salida de la celda anterior y la convierte en alguna forma que se puede tomar como entrada a la siguiente celda. Es una transformación no lineal que hacemos para las entradas que recibimos antes de enviarlas a la siguiente capa o neurona. El AF también se conoce como función de transferencia. Para obtener más información sobre AF, visite el siguiente enlace (https://www.analyticsvidhya.com/blog/2021/06/artificial-neural-networks-better-understanding/)

# %% [markdown]
# ### Pooling
#
# Todos sabemos la importancia de la piscina, ¿verdad? rompe el estrés, si nadamos durante una hora, cualquier estrés que tengamos desaparecerá, de la misma manera, el proceso de pooling, lo que significa que reduce la dimensionalidad de nuestra matriz. La principal importancia de la puesta en común es reducir el sobreajuste y la computación en nuestro conjunto de datos. En un nivel laico, la agrupación se puede explicar por,
#
# La principal importancia de la capa de agrupación es detectar los bordes, las esquinas y en imágenes similares a las de la aplicación, se puede utilizar para detectar rasgos faciales como la nariz y los ojos mediante el uso de múltiples filtros. Es como filtrar el mapa de características, porque obtenemos el mapa de características del proceso de convolución, y aquí en la agrupación lo vamos a aplicar al filtro. En su mayoría, el tamaño del filtro es 2*2, lo que significa que en el proceso de agrupación, el mapa de características se reduce en un factor de 2 (en simple, reducido a la mitad de la dimensión del mapa de características), internamente, reduce cada valor en el mapa de características a una cuarta parte.
#
# Tiene dos tipos principales, Max-Pooling y Avg-Pooling.
#
# ![picture](https://editor.analyticsvidhya.com/uploads/92473a1.png)
#
# ![picture](https://editor.analyticsvidhya.com/uploads/49776avg.png)

# %% [markdown]
# ### Flattening
#
# Así que la siguiente capa después del proceso de agrupación es aplanada, aquí en este proceso, vamos a convertir nuestra matriz en una sola columna, básicamente, estamos tomando números de fila por fila y poniéndolos en una sola columna.
#
# ![picture](https://editor.analyticsvidhya.com/uploads/88334f.png)
#
# Y la importancia de convertirlos en una sola columna es simple, el siguiente paso es alimentarlos a la red neuronal para su posterior procesamiento.
#
# El aplanamiento es convertir los datos en una matriz de 1 dimensión para introducirlos en la siguiente capa. Aplanamos la salida de las capas convolucionales para crear un vector de una sola característica larga. Y está relacionado con el modelo de clasificación final, que se llama capa totalmente conectada.
#
# En otras palabras, ponemos todos los datos de píxeles en una línea y hacemos conexiones con la capa final. Y una vez más. ¿Para qué es la capa final?

# %% [markdown]
# ### Full connection / Fully connected layer
#
# Última capa, en la que cada píxel o cada número/punto se considera como una neurona separada al igual que una NN. La última capa completamente conectada contendrá tantas neuronas como el número de clases a predecir.
#
#
# Ahora que hemos convertido nuestra imagen de entrada en una forma adecuada para nuestra arquitectura multinivel totalmente conectada, aplanaremos la imagen en un vector de columna. La salida aplanada se alimenta a una red neuronal de alimentación y la repropagación se aplica a cada iteración de entrenamiento. A lo largo de una serie de épocas, el modelo puede distinguir entre características dominantes y ciertas características de bajo nivel en las imágenes y clasificarlas.
#
# Esta capa asigna pesos aleatorios a las entradas y predice una etiqueta adecuada
#
# Además de estos bloques, también hay algunos bloques especiales utilizados para CNN,

# %% [markdown]
# ### Implementación de CNN
#
# La malaría es una enfermedad de la sangre causada por los parásitos Plasmodium, que se transmite a través de la picadura del mosquito hembra Anopheles. En 2016, OMS informó de 212 millones de casos de ésta enfermedad. Los exámenes microscópicos de frotis de sangre gruesos y delgados son los métodos más confiable y comúnmente utilizando para el diagnóstico de enfermedades.
#
# La frotis de sangre gruesos ayudan a detectar la presencia de parásitos, mientras que los frotis de sangre finos ayudan a identificar la especie de parásito que causa la infección. Estos análisis dependen de la experiencia humana y uede verse afectadanegativamente por la variabilidad entre observacdores y la responsibilidad impuesta por los diagnosticos a gran escala en regiones como enfermedades endémicas o recursos limitados.
#
# Los investigadores de  Lister Hill National Center for Biomedical Communications (LHNCBC) desarrollaron una aplicación móvil que se ejecuta en un telefono android y se conecta al microscopio de luz convencional. Se recolectaron y fotografiaron frotis de sangre finos para pacientes infectados y sanos. Las imagenes fueron anotadas manualmente por un expero de la Mahidol-Oxford Tropical Medicine Research Unit in Bangkok.  Este conjunto de archivos se encuentra en NLM (IRB#12972) (Rajaraman et al. 2018).
#
# Utilizaremos CNN para clasificar las células infectadas con parásitos de la malaria y las células normales no infectadas usando imagenes de microscopía óptica. Este conjunto de datos contiene 27558 imágenes de células con instancias iguales de células parasitadas y no infectadas. Sin embargo, para que este proyecto sea manor exhaustivo desde el punto de visto computacional, seleccionamos 1000 imágenes de cada clase.
#
#
#
# https://lhncbc.nlm.nih.gov/LHC-downloads/downloads.html#malaria-datasets

# %%
#Importamos algunos módulos necesarios
import os
import numpy as np
import random as rn
from PIL import Image
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos autilizar algunas bibliotecas que nos permiten cargar cada una de las imagenes de manera individual

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten,Dropout,Conv2D,MaxPool2D
from tensorflow.keras.backend import resize_images

# %%
#Visualizamos los archivos de desde un directorio específico.
print(os.listdir("./datos"))
# Out:
# ['Uninfected_1000', 'Parasitized_1000']

# %%
# Vamos a crear una función que nos permita leer cada imagen, cambiar el tamaño a 64x64 pixeles,
# Las convierte y agrega a una matriz de Numpy, devuelve la matriz adjunta con todas las imágenes.
# Por último, devuelve la matriz adjunta con todas las imágenes.
def image_loader(dr):
    IMG_list = []
    read = lambda im: np.asarray(Image.open(im).
                                 convert("RGB").resize((64, 64)))
    for image_file in os.listdir(dr):
        Path = os.path.join(dr,image_file)
        _, ftype = os.path.splitext(Path)
        if ftype == ".png":
            img = read(Path)
            IMG_list.append(np.array(img)/255.)


    return IMG_list

# %%
# Vamos a leer las 1000 imagenes para cada tipo de datos.
# Las imagenes fueron redimensionadas para que ocupen menos memoria.
Parasitized = np.array(image_loader('./datos/Parasitized_1000'))
Uninfected = np.array(image_loader('./datos/Uninfected_1000'))

# %%
# Aquí generamos 1000 ceros y 1000 unos para etiquetar el conjunto de datos, donde las células no infectadas se etiquetan como "0"
# y las células infectadas o parasitadas se etiqeutan como "1".
Uninfected_label = np.zeros(len(Uninfected))
Parasitized_label = np.ones(len(Parasitized))

# %%
Parasitized.shape
# Out:
# (1000, 64, 64, 3)

# %% [markdown]
# #### Dividir el conjunto de datos en el conjunto de entrenamiento y el conjnto de prueba

# %%
# Unimos los datos
# Las imágenes se asignan a la variable independiente (es decir X)
# y las etiquetas se almacenan en la variable y.
X = np.concatenate((Uninfected, Parasitized), axis = 0)
y = np.concatenate((Uninfected_label, Parasitized_label), axis = 0)

#Ahora el conjunto de datos se divide aleatoriamente en entrenamiento y prueba, caracteristicas y etiquetas, espectivamente.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
#Podemos ver algunas de las imagenes en el conjunto de entrenamiento

fig=plt.figure(figsize=(10,10))


for i in range(1, 13):
    ax = fig.add_subplot(3, 4, i)
    if y_train[i] == 0:
        ax.title.set_text('Uninfected')
    else:
        ax.title.set_text('Parasitized')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# El modelo contiene siete capas además de las capas de abandono, estas son:
# 1. La capa de convolución 3x3 y 16 filtros con la función de activación ReLU.
# 2. La capa de max pool con tamaño 2x2
# 3. La segunda capa de convolución con 64 filtros de dimensión 3x3 y la función de activación ReLU
# 4. La segunda capa de max pool de tamaño 2x2
# 5. La capa flatten
# 6. La capa densamente conectada con 64 neuronas con la función de activación ReLU
# 7. Una sola neurona con función sigmoidea para clasificación binaria.
#
# El modelo se compila con la función de pérdida "binary_crossentropy" y el optimizador "rmsprop"

# %%
model = Sequential()
model.add(Conv2D(16,(3,3),activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 31, 31, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                802880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 812,673
# Trainable params: 812,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento del modelo
#
# En este caso debido a que la época completa es demasiado grande, será difícil entrenar todas las épocas a la vez debido a la limitación de la memoria.
#
# Por lo que vamos a dividir la época en lotes y luego entrenaremos un lote a la vez.
#
# Tomaremos ocho imágenes por lote. Para el resto adicionaremos early stopping callback.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.fit(x=X_train,
          y=y_train,
          epochs=400,
          batch_size= 8,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
# ----> 2 model.fit(x=X_train,
#       3           y=y_train,
#       4           epochs=400,
#       5           batch_size= 8,
#       6           validation_data=(X_test, y_test), verbose=1,
#       7           callbacks=[early_stop]
#       8           )
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/training.py:1137, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1131   self._cluster_coordinator = cluster_coordinator.ClusterCoordinator(
#    1132       self.distribute_strategy)
#    1134 with self.distribute_strategy.scope(), \
#    1135      training_utils.RespectCompiledTrainableState(self):
#    1136   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1137   data_handler = data_adapter.get_data_handler(
#    1138       x=x,
#    1139       y=y,
#    1140       sample_weight=sample_weight,
#    1141       batch_size=batch_size,
#    1142       steps_per_epoch=steps_per_epoch,
#    1143       initial_epoch=initial_epoch,
#    1144       epochs=epochs,
#    1145       shuffle=shuffle,
#    1146       class_weight=class_weight,
#    1147       max_queue_size=max_queue_size,
#    1148       workers=workers,
#    1149       use_multiprocessing=use_multiprocessing,
#    1150       model=self,
#    1151       steps_per_execution=self._steps_per_execution)
#    1153   # Container that configures and calls `tf.keras.Callback`s.
#    1154   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:1397, in get_data_handler(*args, **kwargs)
#    1395 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1396   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1397 return DataHandler(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:1151, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1148   self._steps_per_execution = steps_per_execution
#    1149   self._steps_per_execution_value = steps_per_execution.numpy().item()
# -> 1151 adapter_cls = select_data_adapter(x, y)
#    1152 self._adapter = adapter_cls(
#    1153     x,
#    1154     y,
#    (...)
#    1163     distribution_strategy=distribute_lib.get_strategy(),
#    1164     model=model)
#    1166 strategy = distribute_lib.get_strategy()
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:987, in select_data_adapter(x, y)
#     985 def select_data_adapter(x, y):
#     986   """Selects a data adapter than can handle a given x and y."""
# --> 987   adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#     988   if not adapter_cls:
#     989     # TODO(scottzhu): This should be a less implementation-specific error.
#     990     raise ValueError(
#     991         "Failed to find data adapter that can handle "
#     992         "input: {}, {}".format(
#     993             _type_name(x), _type_name(y)))
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:987, in <listcomp>(.0)
#     985 def select_data_adapter(x, y):
#     986   """Selects a data adapter than can handle a given x and y."""
# --> 987   adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#     988   if not adapter_cls:
#     989     # TODO(scottzhu): This should be a less implementation-specific error.
#     990     raise ValueError(
#     991         "Failed to find data adapter that can handle "
#     992         "input: {}, {}".format(
#     993             _type_name(x), _type_name(y)))
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:706, in DatasetAdapter.can_handle(x, y)
#     703 @staticmethod
#     704 def can_handle(x, y=None):
#     705   return (isinstance(x, (data_types.DatasetV1, data_types.DatasetV2)) or
# --> 706           _is_distributed_dataset(x))
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/keras/engine/data_adapter.py:1696, in _is_distributed_dataset(ds)
#    1695 def _is_distributed_dataset(ds):
# -> 1696   return isinstance(ds, input_lib.DistributedDatasetInterface)
#
# AttributeError: module 'tensorflow.python.distribute.input_lib' has no attribute 'DistributedDatasetInterface'

# %%
#Verificamos si nuestro modelo tiene sobreajuste
#En este caso no observamos
import pandas as pd
model_loss = pd.DataFrame(model.history.history)
model_loss[['loss','val_loss']].plot()

# %% [markdown]
# #### Evaluación del modelo

# %%
predictions = model.predict_classes(X_test)
from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))

# %% [markdown]
# El modelo ha logrado una tasa de exactitud del 86% en el conjunto de prueba. El modelo se puede mejorar más aumentado la espera del objeto eraly stopping, ya que hemos observado que el modelo puede tener picos inciertos durante el entrenamiento
